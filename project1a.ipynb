# %%
from tkinter import *
import tkinter.messagebox
window = Tk()
window.title("Tic-Tac-Toe-Game")
buttons = StringVar()
flag = 1
turn=1

def enter(buttons):
    global bclick,flag,turn
    if buttons["text"]==" ":
        if turn==1:
            buttons["text"]="X"
            turn=0
            check()
            flag=flag+1
        elif turn== 0:
            buttons["text"]="O"
            turn=1
            check()
            flag=flag+1
    else:
        tkinter.messagebox.showinfo("Tic-Tac-Toe", "Button already Clicked!") 
        
        
def check():
    if (button1['text'] == 'X' and button2['text'] == 'X' and button3['text'] == 'X' or
        button4['text'] == 'X' and button5['text'] == 'X' and button6['text'] == 'X' or
        button7['text'] =='X' and button8['text'] == 'X' and button9['text'] == 'X' or
        button1['text'] == 'X' and button5['text'] == 'X' and button9['text'] == 'X' or
        button3['text'] == 'X' and button5['text'] == 'X' and button7['text'] == 'X' or
        button1['text'] == 'X' and button4['text'] == 'X' and button7['text'] == 'X' or
        button2['text'] == 'X' and button5['text'] == 'X' and button8['text'] == 'X' or
        button3['text'] == 'X' and button6['text'] == 'X' and button9['text'] == 'X'):
        disable()
        tkinter.messagebox.showinfo("Tic-Tac-Toe","player1 wins")
        window.destroy()
    elif(flag == 9):
        tkinter.messagebox.showinfo("Tic-Tac-Toe", "It is a Tie")
        window.destroy()
    elif (button1['text'] == 'O' and button2['text'] == 'O' and button3['text'] == 'O' or
          button4['text'] == 'O' and button5['text'] == 'O' and button6['text'] == 'O' or
          button7['text'] == 'O' and button8['text'] == 'O' and button9['text'] == 'O' or
          button1['text'] == 'O' and button5['text'] == 'O' and button9['text'] == 'O' or
          button3['text'] == 'O' and button5['text'] == 'O' and button7['text'] == 'O' or
          button1['text'] == 'O' and button4['text'] == 'O' and button7['text'] == 'O' or
          button2['text'] == 'O' and button5['text'] == 'O' and button8['text'] == 'O' or
          button3['text'] == 'O' and button6['text'] == 'O' and button9['text'] == 'O'):
        disable()
        tkinter.messagebox.showinfo("Tic-Tac-Toe", "player2 wins")
        window.destroy()

        
def disable():
    button1.configure(state=DISABLED)
    button2.configure(state=DISABLED)
    button3.configure(state=DISABLED)
    button4.configure(state=DISABLED)
    button5.configure(state=DISABLED)
    button6.configure(state=DISABLED)
    button7.configure(state=DISABLED)
    button8.configure(state=DISABLED)
    button9.configure(state=DISABLED)        

    
label = Label( window, text="Player 1:", font='Helvetica', bg='white', fg='black', height=1, width=8)
label.grid(row=1, column=0)


label = Label( window, text="Player 2:", font='Helvetica', bg='white', fg='black', height=1, width=8)
label.grid(row=2, column=0)

button1 = Button(window, text=" ", font='Helvetica', bg='lightblue', fg='black', height=5, width=9,command=lambda:enter(button1))
button1.grid(row=3, column=0)

button2 = Button(window, text=' ', font='Helvetica', bg='lightblue', fg='black', height=5, width=9,command=lambda:enter(button2))
button2.grid(row=3, column=1)

button3 = Button(window, text=' ',font='Helvetica', bg='lightblue', fg='black', height=5, width=9,command=lambda:enter(button3))
button3.grid(row=3, column=2)

button4 = Button(window, text=' ', font='Helvetica', bg='lightblue', fg='black', height=5, width=9,command=lambda:enter(button4))
button4.grid(row=4, column=0)

button5 = Button(window, text=' ', font='Helvetica', bg='lightblue', fg='black', height=5, width=9,command=lambda:enter(button5))
button5.grid(row=4, column=1)

button6 = Button(window, text=' ', font='Helvetica', bg='lightblue', fg='black', height=5, width=9,command=lambda:enter(button6))
button6.grid(row=4, column=2)

button7 = Button(window, text=' ', font='Helvetica', bg='lightblue', fg='black', height=5, width=9,command=lambda:enter(button7))
button7.grid(row=5, column=0)

button8 = Button(window, text=' ', font='Helvetica', bg='lightblue', fg='black', height=5, width=9,command=lambda:enter(button8))
button8.grid(row=5, column=1)

button9 = Button(window, text=' ', font='Helvetica', bg='lightblue', fg='black', height=5, width=9,command=lambda:enter(button9))
button9.grid(row=5, column=2)

window.mainloop()
